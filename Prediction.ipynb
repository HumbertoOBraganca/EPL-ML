# %%
import pandas as pd

# %%
matches = pd.read_csv('matches.csv', index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2023-08-12  12:30  Premier League  Matchweek 1  Sat  Home      W  2.0  1.0
# 2  2023-08-21  20:00  Premier League  Matchweek 2  Mon  Away      W  1.0  0.0
# 3  2023-08-26  15:00  Premier League  Matchweek 3  Sat  Home      D  2.0  2.0
# 4  2023-09-03  16:30  Premier League  Matchweek 4  Sun  Home      W  3.0  1.0
# 5  2023-09-17  16:30  Premier League  Matchweek 5  Sun  Away      W  1.0  0.0
#
#           opponent  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# 1  Nott'ham Forest  ...  Match Report    NaN  15.0  7.0  19.1  0.0  0     0
# 2   Crystal Palace  ...  Match Report    NaN  13.0  2.0  16.4  0.0  1     1
# 3           Fulham  ...  Match Report    NaN  18.0  9.0  13.8  0.0  1     1
# 4   Manchester Utd  ...  Match Report    NaN  17.0  5.0  15.0  0.0  0     0
# 5          Everton  ...  Match Report    NaN  13.0  4.0  17.4  0.0  0     0
#
#   season     team
# 1   2024  Arsenal
# 2   2024  Arsenal
# 3   2024  Arsenal
# 4   2024  Arsenal
# 5   2024  Arsenal
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (1326, 27)

# %%
matches['team'].value_counts()
# Out:
# team
# Fulham                      67
# Newcastle United            67
# Nottingham Forest           67
# Brentford                   67
# Wolverhampton Wanderers     67
# Everton                     66
# Crystal Palace              66
# Bournemouth                 66
# Liverpool                   66
# Arsenal                     66
# Brighton and Hove Albion    66
# West Ham United             66
# Manchester United           66
# Tottenham Hotspur           66
# Aston Villa                 66
# Manchester City             66
# Chelsea                     65
# Leicester City              38
# Leeds United                38
# Southampton                 38
# Luton Town                  29
# Burnley                     29
# Sheffield United            28
# Name: count, dtype: int64

# %%
matches['round'].value_counts()
# Out:
# round
# Matchweek 1     40
# Matchweek 15    40
# Matchweek 28    40
# Matchweek 27    40
# Matchweek 25    40
# Matchweek 24    40
# Matchweek 23    40
# Matchweek 22    40
# Matchweek 21    40
# Matchweek 2     40
# Matchweek 19    40
# Matchweek 18    40
# Matchweek 17    40
# Matchweek 16    40
# Matchweek 20    40
# Matchweek 14    40
# Matchweek 7     40
# Matchweek 3     40
# Matchweek 13    40
# Matchweek 5     40
# Matchweek 6     40
# Matchweek 4     40
# Matchweek 8     40
# Matchweek 9     40
# Matchweek 10    40
# Matchweek 11    40
# Matchweek 12    40
# Matchweek 26    38
# Matchweek 29    28
# Matchweek 30    20
# Matchweek 31    20
# Matchweek 33    20
# Matchweek 34    20
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 32    20
# Matchweek 38    20
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes            object
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk                int64
# pkatt             int64
# season            int64
# team             object
# dtype: object

# %%
matches['date'] = pd.to_datetime(matches['date'])

# %%
# atribuir valores numericos a coluna 'venue'
matches['venue_code'] = matches['venue'].astype('category').cat.codes

# %%
# atribuir valores numericos a coluna 'opponent'
matches['opp_code'] = matches['opponent'].astype('category').cat.codes

# %%
# mudar o horario para apenas os dois primeiros digitos. Ex: 16:30 => 16
matches['hour'] = matches['time'].str.replace(':.+','', regex=True).astype('int')

# %%
# atribuir valores numericos ao dia da semana. Ex: monday=1, tuesday=2, ...
matches['day_code'] = matches['date'].dt.dayofweek

# %%
matches['target'] = (matches['result'] == 'W').astype('int')

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# n_estimaotrs, the higher more precise it gets
# min_samples_split the higher less precise
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches['date'] < '2024-01-01']

# %%
teste = matches[matches['date'] > '2024-01-01']

# %%
predictors = ['venue_code', 'opp_code', 'hour', 'day_code']

# %%
rf.fit(train[predictors], train['target'])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict((teste[predictors]))

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(teste['target'], preds)

# %%
acc
# Out:
# 0.5930232558139535

# %%
combined = pd.DataFrame(dict(actual=teste['target'], prediction=preds))

# %%
pd.crosstab(index=combined['actual'], columns=combined['prediction'])
# Out:
# prediction   0   1
# actual
# 0           80  29
# 1           41  22

# %%
from sklearn.metrics import precision_score

# %%
precision_score(teste['target'], preds)
# Out:
# 0.43137254901960786

# %%
 grouped_matches = matches.groupby('team')

# %%
group = grouped_matches.get_group('Manchester City')

# %%
group
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W  3.0
# 3  2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W  1.0
# 4  2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W  2.0
# 5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W  5.0
# 6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W  3.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 52 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W  2.0
# 54 2023-05-14  14:00  Premier League  Matchweek 36  Sun  Away      W  3.0
# 56 2023-05-21  16:00  Premier League  Matchweek 37  Sun  Home      W  1.0
# 57 2023-05-24  20:00  Premier League  Matchweek 32  Wed  Away      D  1.0
# 58 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L  0.0
#
#      ga       opponent  ...   fk  pk  pkatt  season             team  \
# 1   0.0        Burnley  ...  0.0   0      0    2024  Manchester City
# 3   0.0  Newcastle Utd  ...  0.0   0      0    2024  Manchester City
# 4   1.0  Sheffield Utd  ...  2.0   0      1    2024  Manchester City
# 5   1.0         Fulham  ...  0.0   1      1    2024  Manchester City
# 6   1.0       West Ham  ...  1.0   0      0    2024  Manchester City
# ..  ...            ...  ...  ...  ..    ...     ...              ...
# 52  1.0   Leeds United  ...  2.0   0      1    2023  Manchester City
# 54  0.0        Everton  ...  2.0   0      0    2023  Manchester City
# 56  0.0        Chelsea  ...  0.0   0      0    2023  Manchester City
# 57  1.0       Brighton  ...  0.0   0      0    2023  Manchester City
# 58  1.0      Brentford  ...  0.0   0      0    2023  Manchester City
#
#    venue_code opp_code hour day_code  target
# 1           0        5   20        4       1
# 3           1       16   20        5       1
# 4           0       18   14        6       1
# 5           1        9   15        5       1
# 6           0       21   15        5       1
# ..        ...      ...  ...      ...     ...
# 52          1       10   15        5       1
# 54          0        8   14        6       1
# 56          1        6   16        6       1
# 57          0        4   20        2       0
# 58          0        3   16        6       0
#
# [66 rows x 32 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values('date')
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ['gf', 'ga', 'sh', 'sot', 'dist', 'fk', 'pk', 'pkatt']
new_cols = [f'{c}_rolling' for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 4  2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W  4.0
# 5  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  6.0
# 6  2022-09-03  17:30  Premier League   Matchweek 6  Sat  Away      D  1.0
# 9  2022-09-17  12:30  Premier League   Matchweek 8  Sat  Away      W  3.0
# 10 2022-10-02  14:00  Premier League   Matchweek 9  Sun  Home      W  6.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 35 2024-02-17  17:30  Premier League  Matchweek 25  Sat  Home      D  1.0
# 36 2024-02-20  19:30  Premier League  Matchweek 18  Tue  Home      W  1.0
# 37 2024-02-24  17:30  Premier League  Matchweek 26  Sat  Away      W  1.0
# 39 2024-03-03  15:30  Premier League  Matchweek 27  Sun  Home      W  3.0
# 41 2024-03-10  15:45  Premier League  Matchweek 28  Sun  Away      D  1.0
#
#      ga         opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 4   2.0   Crystal Palace  ...         5       1    3.000000    1.000000
# 5   0.0  Nott'ham Forest  ...         2       1    3.666667    1.666667
# 6   1.0      Aston Villa  ...         5       0    4.333333    1.666667
# 9   0.0           Wolves  ...         5       1    3.666667    1.000000
# 10  3.0   Manchester Utd  ...         6       1    3.333333    0.333333
# ..  ...              ...  ...       ...     ...         ...         ...
# 35  1.0          Chelsea  ...         5       0    2.666667    0.666667
# 36  0.0        Brentford  ...         1       1    2.000000    0.666667
# 37  0.0      Bournemouth  ...         5       1    1.333333    0.333333
# 39  1.0   Manchester Utd  ...         6       1    1.000000    0.333333
# 41  1.0        Liverpool  ...         6       0    1.666667    0.333333
#
#    sh_rolling sot_rolling dist_rolling fk_rolling pk_rolling  pkatt_rolling
# 4   17.666667    6.000000    17.466667   0.666667   0.333333       0.333333
# 5   19.333333    7.333333    15.933333   0.333333   0.000000       0.000000
# 6   18.666667    8.000000    15.033333   0.333333   0.000000       0.000000
# 9   16.000000    6.000000    15.233333   0.333333   0.000000       0.000000
# 10  15.333333    6.666667    17.000000   0.333333   0.000000       0.000000
# ..        ...         ...          ...        ...        ...            ...
# 35  19.333333    7.333333    17.466667   0.333333   0.000000       0.000000
# 36  25.000000    7.666667    17.500000   0.333333   0.000000       0.000000
# 37  25.000000    6.000000    16.966667   0.333333   0.000000       0.000000
# 39  23.666667    7.000000    16.333333   0.666667   0.000000       0.000000
# 41  22.333333    8.000000    16.933333   0.666667   0.000000       0.000000
#
# [63 rows x 40 columns]

# %%
matches_rolling = matches.groupby('team').apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 3  2022-08-27  17:30  Premier League   Matchweek 4
#                         4  2022-08-31  19:30  Premier League   Matchweek 5
#                         5  2022-09-04  16:30  Premier League   Matchweek 6
#                         7  2022-09-18  12:00  Premier League   Matchweek 8
#                         8  2022-10-01  12:30  Premier League   Matchweek 9
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 29 2024-02-17  15:00  Premier League  Matchweek 25
#                         30 2024-02-25  13:30  Premier League  Matchweek 26
#                         32 2024-03-02  15:00  Premier League  Matchweek 27
#                         33 2024-03-09  15:00  Premier League  Matchweek 28
#                         35 2024-03-16  15:00  Premier League  Matchweek 29
#
#                             day venue result   gf   ga        opponent  ...  \
# team                                                                    ...
# Arsenal                 3   Sat  Home      W  2.0  1.0          Fulham  ...
#                         4   Wed  Home      W  2.0  1.0     Aston Villa  ...
#                         5   Sun  Away      L  1.0  3.0  Manchester Utd  ...
#                         7   Sun  Away      W  3.0  0.0       Brentford  ...
#                         8   Sat  Home      W  3.0  1.0       Tottenham  ...
# ...                         ...   ...    ...  ...  ...             ...  ...
# Wolverhampton Wanderers 29  Sat  Away      W  2.0  1.0       Tottenham  ...
#                         30  Sun  Home      W  1.0  0.0   Sheffield Utd  ...
#                         32  Sat  Away      L  0.0  3.0   Newcastle Utd  ...
#                         33  Sat  Home      W  2.0  1.0          Fulham  ...
#                         35  Sat  Home    NaN  NaN  NaN     Bournemouth  ...
#
#                             day_code  target  gf_rolling  ga_rolling  \
# team
# Arsenal                 3          5       1    3.000000    0.666667
#                         4          2       1    3.000000    1.000000
#                         5          6       0    2.333333    0.666667
#                         7          6       1    1.666667    1.666667
#                         8          5       1    2.000000    1.333333
# ...                              ...     ...         ...         ...
# Wolverhampton Wanderers 29         5       1    2.333333    2.666667
#                         30         6       1    2.000000    1.666667
#                         32         5       0    1.000000    1.000000
#                         33         5       1    1.000000    1.333333
#                         35         5       0    1.000000    1.333333
#
#                            sh_rolling sot_rolling dist_rolling fk_rolling  \
# team
# Arsenal                 3   14.333333    5.000000    14.133333   0.333333
#                         4   18.333333    7.000000    14.433333   0.333333
#                         5   19.333333    7.333333    15.533333   0.666667
#                         7   20.000000    6.333333    16.800000   1.000000
#                         8   17.000000    6.000000    17.700000   0.666667
# ...                               ...         ...          ...        ...
# Wolverhampton Wanderers 29  15.000000    5.333333    16.800000   1.333333
#                         30  14.000000    6.000000    16.566667   1.000000
#                         32  14.000000    4.666667    15.900000   0.333333
#                         33  12.333333    4.000000    15.466667   0.000000
#                         35  11.000000    2.666667    15.600000   0.000000
#
#                            pk_rolling  pkatt_rolling
# team
# Arsenal                 3    0.000000       0.000000
#                         4    0.000000       0.000000
#                         5    0.000000       0.000000
#                         7    0.000000       0.000000
#                         8    0.000000       0.000000
# ...                               ...            ...
# Wolverhampton Wanderers 29   0.666667       0.666667
#                         30   0.333333       0.333333
#                         32   0.000000       0.000000
#                         33   0.000000       0.000000
#                         35   0.000000       0.000000
#
# [1257 rows x 40 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W  2.0
# 1    2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  2.0
# 2    2022-09-04  16:30  Premier League   Matchweek 6  Sun  Away      L  1.0
# 3    2022-09-18  12:00  Premier League   Matchweek 8  Sun  Away      W  3.0
# 4    2022-10-01  12:30  Premier League   Matchweek 9  Sat  Home      W  3.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 1252 2024-02-17  15:00  Premier League  Matchweek 25  Sat  Away      W  2.0
# 1253 2024-02-25  13:30  Premier League  Matchweek 26  Sun  Home      W  1.0
# 1254 2024-03-02  15:00  Premier League  Matchweek 27  Sat  Away      L  0.0
# 1255 2024-03-09  15:00  Premier League  Matchweek 28  Sat  Home      W  2.0
# 1256 2024-03-16  15:00  Premier League  Matchweek 29  Sat  Home    NaN  NaN
#
#        ga        opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 0     1.0          Fulham  ...         5       1    3.000000    0.666667
# 1     1.0     Aston Villa  ...         2       1    3.000000    1.000000
# 2     3.0  Manchester Utd  ...         6       0    2.333333    0.666667
# 3     0.0       Brentford  ...         6       1    1.666667    1.666667
# 4     1.0       Tottenham  ...         5       1    2.000000    1.333333
# ...   ...             ...  ...       ...     ...         ...         ...
# 1252  1.0       Tottenham  ...         5       1    2.333333    2.666667
# 1253  0.0   Sheffield Utd  ...         6       1    2.000000    1.666667
# 1254  3.0   Newcastle Utd  ...         5       0    1.000000    1.000000
# 1255  1.0          Fulham  ...         5       1    1.000000    1.333333
# 1256  NaN     Bournemouth  ...         5       0    1.000000    1.333333
#
#      sh_rolling sot_rolling dist_rolling fk_rolling pk_rolling  pkatt_rolling
# 0     14.333333    5.000000    14.133333   0.333333   0.000000       0.000000
# 1     18.333333    7.000000    14.433333   0.333333   0.000000       0.000000
# 2     19.333333    7.333333    15.533333   0.666667   0.000000       0.000000
# 3     20.000000    6.333333    16.800000   1.000000   0.000000       0.000000
# 4     17.000000    6.000000    17.700000   0.666667   0.000000       0.000000
# ...         ...         ...          ...        ...        ...            ...
# 1252  15.000000    5.333333    16.800000   1.333333   0.666667       0.666667
# 1253  14.000000    6.000000    16.566667   1.000000   0.333333       0.333333
# 1254  14.000000    4.666667    15.900000   0.333333   0.000000       0.000000
# 1255  12.333333    4.000000    15.466667   0.000000   0.000000       0.000000
# 1256  11.000000    2.666667    15.600000   0.000000   0.000000       0.000000
#
# [1257 rows x 40 columns]

# %%
def make_predictions(data, predictors):
    train = data[data['date'] < '2024-01-01']
    teste = data[data['date'] > '2024-01-01']
    rf.fit(train[predictors], train['target'])
    preds = rf.predict((teste[predictors]))
    combined = pd.DataFrame(dict(actual=teste['target'], prediction=preds))
    precision = precision_score(teste['target'], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.5961538461538461

# %%
combined
# Out:
#       actual  prediction
# 55         1           1
# 56         1           1
# 57         1           1
# 58         1           0
# 59         1           0
# ...      ...         ...
# 1252       1           0
# 1253       1           1
# 1254       0           0
# 1255       1           1
# 1256       0           0
#
# [172 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[['date', 'team', 'opponent', 'result']], left_index=True, right_index=True)

# %%
combined
# Out:
#       actual  prediction       date                     team         opponent  \
# 55         1           1 2024-01-20                  Arsenal   Crystal Palace
# 56         1           1 2024-01-30                  Arsenal  Nott'ham Forest
# 57         1           1 2024-02-04                  Arsenal        Liverpool
# 58         1           0 2024-02-11                  Arsenal         West Ham
# 59         1           0 2024-02-17                  Arsenal          Burnley
# ...      ...         ...        ...                      ...              ...
# 1252       1           0 2024-02-17  Wolverhampton Wanderers        Tottenham
# 1253       1           1 2024-02-25  Wolverhampton Wanderers    Sheffield Utd
# 1254       0           0 2024-03-02  Wolverhampton Wanderers    Newcastle Utd
# 1255       1           1 2024-03-09  Wolverhampton Wanderers           Fulham
# 1256       0           0 2024-03-16  Wolverhampton Wanderers      Bournemouth
#
#      result
# 55        W
# 56        W
# 57        W
# 58        W
# 59        W
# ...     ...
# 1252      W
# 1253      W
# 1254      L
# 1255      W
# 1256    NaN
#
# [172 rows x 6 columns]

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key
    
map_values = {
    'Brighton and Hove Albion': 'Brighton',
    'Manchester United': 'Manchester Utd',
    'Newcastle United': 'Newcastle Utd',
    'Tottenham Hotspur': 'Tottenham',
    'West Ham United': 'West Ham',
    'Wolverhampton Wanderers': 'Wolves'
}
mapping = MissingDict(**map_values)

# %%
mapping['West Ham United']
# Out:
# 'West Ham'

# %%
combined['new_team'] = combined['team'].map(mapping)

# %%
combined
# Out:
#       actual  prediction       date                     team         opponent  \
# 55         1           1 2024-01-20                  Arsenal   Crystal Palace
# 56         1           1 2024-01-30                  Arsenal  Nott'ham Forest
# 57         1           1 2024-02-04                  Arsenal        Liverpool
# 58         1           0 2024-02-11                  Arsenal         West Ham
# 59         1           0 2024-02-17                  Arsenal          Burnley
# ...      ...         ...        ...                      ...              ...
# 1252       1           0 2024-02-17  Wolverhampton Wanderers        Tottenham
# 1253       1           1 2024-02-25  Wolverhampton Wanderers    Sheffield Utd
# 1254       0           0 2024-03-02  Wolverhampton Wanderers    Newcastle Utd
# 1255       1           1 2024-03-09  Wolverhampton Wanderers           Fulham
# 1256       0           0 2024-03-16  Wolverhampton Wanderers      Bournemouth
#
#      result new_team
# 55        W  Arsenal
# 56        W  Arsenal
# 57        W  Arsenal
# 58        W  Arsenal
# 59        W  Arsenal
# ...     ...      ...
# 1252      W   Wolves
# 1253      W   Wolves
# 1254      L   Wolves
# 1255      W   Wolves
# 1256    NaN   Wolves
#
# [172 rows x 7 columns]

# %%
merged = combined.merge(combined, left_on=['date','new_team'], right_on=['date', 'opponent'])

# %%
merged
# Out:
#      actual_x  prediction_x       date                   team_x  \
# 0           1             1 2024-01-20                  Arsenal
# 1           1             1 2024-01-30                  Arsenal
# 2           1             1 2024-02-04                  Arsenal
# 3           1             0 2024-02-11                  Arsenal
# 4           1             0 2024-02-17                  Arsenal
# ..        ...           ...        ...                      ...
# 148         0             0 2024-02-10  Wolverhampton Wanderers
# 149         1             0 2024-02-17  Wolverhampton Wanderers
# 150         1             1 2024-02-25  Wolverhampton Wanderers
# 151         0             0 2024-03-02  Wolverhampton Wanderers
# 152         1             1 2024-03-09  Wolverhampton Wanderers
#
#           opponent_x result_x new_team_x  actual_y  prediction_y  \
# 0     Crystal Palace        W    Arsenal         0             0
# 1    Nott'ham Forest        W    Arsenal         0             0
# 2          Liverpool        W    Arsenal         0             0
# 3           West Ham        W    Arsenal         0             0
# 4            Burnley        W    Arsenal         0             0
# ..               ...      ...        ...       ...           ...
# 148        Brentford        L     Wolves         1             0
# 149        Tottenham        W     Wolves         0             1
# 150    Sheffield Utd        W     Wolves         0             0
# 151    Newcastle Utd        L     Wolves         1             1
# 152           Fulham        W     Wolves         0             1
#
#                 team_y opponent_y result_y         new_team_y
# 0       Crystal Palace    Arsenal        L     Crystal Palace
# 1    Nottingham Forest    Arsenal        L  Nottingham Forest
# 2            Liverpool    Arsenal        L          Liverpool
# 3      West Ham United    Arsenal        L           West Ham
# 4              Burnley    Arsenal        L            Burnley
# ..                 ...        ...      ...                ...
# 148          Brentford     Wolves        W          Brentford
# 149  Tottenham Hotspur     Wolves        L          Tottenham
# 150   Sheffield United     Wolves        L   Sheffield United
# 151   Newcastle United     Wolves        W      Newcastle Utd
# 152             Fulham     Wolves        L             Fulham
#
# [153 rows x 13 columns]

# %%
merged[(merged['prediction_x'] == 1) & (merged['prediction_y'] == 0)]['actual_x'].value_counts()
# Out:
# actual_x
# 1    28
# 0    15
# Name: count, dtype: int64

# %%
# Out:
# 0.6511627906976745
